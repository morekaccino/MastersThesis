# %% [markdown]
# # Methodology for Signal Processing in Ion Channel Analysis
#
# ## Data Acquisition
# 1. Obtain noisy digital signals representing the behavior of ion channels from biological experimental data.
# 2. Preprocess the raw signal data by downsampling or filtering, if necessary, to reduce noise and computational complexity.
#
# ## Data Visualization
# 1. Visualize the preprocessed signal data using scatter plots or line plots to gain insights into the signal's characteristics and potential number of states.
#
# ## State Estimation and Clustering
# ### Histogram-based Approach
# 1. Bin the signal data into a specified number of bins.
# 2. Compute the histogram of the binned data to obtain the distribution of signal values.
# 3. Apply a moving average filter to the histogram to smooth the distribution and mitigate the effects of noise.
# 4. Identify peaks in the smoothed histogram that exceed a predefined threshold.
# 5. Estimate the number of states or clusters as the number of significant peaks.
# 6. Perform DBSCAN clustering on the peak coordinates to further refine the number of clusters and identify potential outliers.
#
# ### Gaussian Mixture Model (GMM) Approach
# 1. Fit a GMM to the signal data using varying numbers of components.
# 2. Evaluate the model fit using the Bayesian Information Criterion (BIC) or other information-theoretic criteria.
# 3. Select the optimal number of components (i.e., the number of states) based on the minimum BIC score or other criteria.
# 4. Analyze the means, standard deviations, and weights of the fitted Gaussian distributions for the best GMM to characterize the states.
# 5. Visualize the BIC scores for different numbers of components to assess the model selection process.
#
# ### Bayesian Gaussian Mixture Model (BGMM) Approach
# 1. Fit a BGMM to the signal data using the number of clusters estimated by the DBSCAN approach or the GMM approach.
# 2. Classify the signal data points based on the BGMM predictions, assigning each data point to the most probable state or cluster.
# 3. Compute the confidence scores or posterior probabilities of the classifications.
# 4. Visualize the classified signal data, with the point transparency or color representing the confidence of the classification.
#
# ## Model Evaluation and Selection
# 1. Compare the performance of the different clustering and state estimation approaches using various evaluation metrics, such as silhouette scores, calinski-harabasz scores, or domain-specific criteria.
# 2. Select the most appropriate method or combine the results from multiple methods to obtain the final estimate of the number of states or clusters present in the signal data.
#
# ## Biological Interpretation
# 1. Interpret the estimated number of states in the context of ion channel behavior and biological processes.
# 2. Analyze the characteristics of the identified states, such as their means, standard deviations, and relative prevalence, to gain insights into the underlying biological mechanisms.
# 3. Validate the results by consulting domain experts or comparing them with existing literature or experimental findings.
#
# ## Reporting and Visualization
# 1. Present the results of the state estimation and clustering analysis through clear and informative visualizations, such as scatter plots, histograms, and cluster assignment plots.
# 2. Discuss the strengths and limitations of the applied methodologies, as well as potential areas for future improvement.
# 3. Provide a comprehensive interpretation of the findings and their implications for understanding ion channel dynamics and biological processes.

# %% [markdown]
# # Signal Processing Methodology for Ion Channel Analysis
#
# ## Introduction
# The analysis of ion channel behavior is a crucial area of study in biology, as it provides insights into fundamental cellular processes and plays a significant role in various physiological functions and diseases. However, experimental data obtained from ion channel recordings often presents challenges due to inherent noise and uncertainties. In this research, we developed a comprehensive signal processing methodology to analyze noisy digital signals representing ion channel activity, with the goal of estimating the number of underlying states and characterizing their properties.
#
# ## Data Acquisition and Preprocessing
# We obtained noisy digital signals representing the behavior of ion channels from biological experimental data. These signals exhibit characteristics similar to digital waveforms but with added noise and variability due to the stochastic nature of ion channel dynamics and experimental conditions.
#
# To ensure computational efficiency and reduce the impact of noise, we preprocessed the raw signal data through downsampling or filtering techniques, if necessary. The preprocessing step aimed to retain the essential signal information while mitigating the effects of high-frequency noise or irrelevant components.
#
# ## Data Visualization
# Prior to applying signal processing algorithms, we visualized the preprocessed signal data using scatter plots or line plots. This visualization step allowed us to gain insights into the signal's characteristics, such as potential state levels, noise levels, and overall complexity. It also helped inform the selection and parameterization of subsequent analysis techniques.
#
# ## State Estimation and Clustering
# To estimate the number of underlying states present in the ion channel signal and classify individual data points into their respective states, we employed three complementary approaches: histogram-based analysis, Gaussian Mixture Models (GMMs), and Bayesian Gaussian Mixture Models (BGMMs).
#
# ### Histogram-based Approach
# In the histogram-based approach, we binned the signal data into a specified number of bins and computed the histogram to obtain the distribution of signal values. To mitigate the effects of noise, we applied a moving average filter to the histogram, effectively smoothing the distribution.
#
# We then identified peaks in the smoothed histogram that exceeded a predefined threshold, with the number of significant peaks serving as an estimate of the number of states or clusters present in the signal.
#
# To further refine the state estimation, we performed DBSCAN clustering on the peak coordinates, allowing us to identify potential outliers and obtain a more robust estimate of the number of clusters.
#
# ### Gaussian Mixture Model (GMM) Approach
# The GMM approach involved fitting a Gaussian Mixture Model to the signal data, with varying numbers of components. We evaluated the model fit using the Bayesian Information Criterion (BIC) or other information-theoretic criteria and selected the optimal number of components based on the minimum BIC score or other criteria.
#
# The means, standard deviations, and weights of the fitted Gaussian distributions for the best GMM provided valuable insights into the characteristics of the identified states, such as their central tendencies, spread, and relative prevalence.
#
# We visualized the BIC scores for different numbers of components to assess the model selection process and ensure the chosen number of states was appropriate.
#
# ### Bayesian Gaussian Mixture Model (BGMM) Approach
# Building upon the results from the histogram-based and GMM approaches, we fitted a Bayesian Gaussian Mixture Model (BGMM) to the signal data using the estimated number of clusters or states.
#
# The BGMM allowed us to classify individual data points into their most probable state or cluster based on the model predictions. We computed the confidence scores or posterior probabilities associated with these classifications, providing insights into the certainty of the state assignments.
#
# To facilitate interpretation and analysis, we visualized the classified signal data, with the point transparency or color representing the confidence of the classification.
#
# ## Model Evaluation and Selection
# To ensure the robustness and reliability of our results, we compared the performance of the different clustering and state estimation approaches using various evaluation metrics, such as silhouette scores, calinski-harabasz scores, or domain-specific criteria.
#
# Based on these evaluations, we selected the most appropriate method or combined the results from multiple methods to obtain the final estimate of the number of states or clusters present in the signal data.
#
# ## Biological Interpretation and Validation
# With the estimated number of states and their characteristics, we interpreted the results in the context of ion channel behavior and biological processes. We analyzed the means, standard deviations, and relative prevalence of the identified states to gain insights into the underlying biological mechanisms governing ion channel dynamics.
#
# To validate our findings, we consulted domain experts and compared our results with existing literature or experimental findings in the field of ion channel research. This validation step ensured that our signal processing methodology yielded biologically meaningful and interpretable results.
#
# ## Reporting and Visualization
# Throughout the analysis process, we employed clear and informative visualizations, such as scatter plots, histograms, and cluster assignment plots, to present the results of the state estimation and clustering analysis effectively.
#
# In addition to the visualizations, we discussed the strengths and limitations of the applied methodologies, highlighting potential areas for future improvement or alternative approaches.
#
# Finally, we provided a comprehensive interpretation of the findings, emphasizing their implications for understanding ion channel dynamics and biological processes, as well as their potential applications in related fields.
#
# ## Conclusion
# The developed signal processing methodology addresses the challenges associated with analyzing noisy digital signals representing ion channel behavior. By combining multiple techniques, including histogram-based analysis, Gaussian Mixture Models, and Bayesian Gaussian Mixture Models, we were able to estimate the number of underlying states, characterize their properties, and classify individual data points into their respective states with varying levels of confidence.
#
# Through rigorous evaluation, validation, and interpretation, our methodology yielded biologically meaningful insights into ion channel dynamics and the underlying biological processes. The visualizations and comprehensive reporting facilitated effective communication of the results and their implications for the field of ion channel research.
#
# This methodology paves the way for further advancements in signal processing techniques tailored to the analysis of biological signals, ultimately contributing to a deeper understanding of cellular processes and their potential applications in biomedical research and clinical applications.

# %%
from itertools import combinations, permutations
import numpy as np
import pandas as pd
from sklearn.cluster import DBSCAN

from source.moreka import AxonData
# from sklearn.cluster import DBSCAN
# from sklearn.preprocessing import StandardScaler
# from sklearn.metrics.pairwise import euclidean_distances
# from scipy.spatial.distance import pdist, squareform
import matplotlib.pyplot as plt
# from scipy.stats import poisson
# import tensorflow as tf
# from tensorflow import keras
# from keras.layers import Input, LSTM, RepeatVector
# from keras.models import Model
from sklearn.mixture import BayesianGaussianMixture, GaussianMixture
# import mdn
# import plotly.express as px
from sympy import symbols, Eq, solve
from sim import generate, moving_average

# %%
data_index = 38

# %% [markdown]
# ## Load the data

# %%
data = AxonData(dirname='./data')
df = data[data_index].iloc[::100, :]

print(df.signal.shape)
df.plot(x='time', y='signal', figsize=(30, 5), kind='scatter', alpha=0.5)
# Out:
# (6000,)
# <Axes: xlabel='time', ylabel='signal'>

# %% [markdown]
# ## Find the number of states

# %%
# df.signal find the bins distribution

bins = np.linspace(df.signal.min(), df.signal.max(), 200)
np.digitize(df.signal, bins)
# plot the bins
hists = plt.hist(df.signal, bins=bins, alpha=0.5, color='b')

# find the moving average of hists
ma = moving_average(hists[0], 5)
ma = moving_average(ma, 5)
plt.plot(hists[1][:-1], ma, 'r', linewidth=5, label='moving average')

# find number of peaks in the moving average that are above a certain threshold
threshold = 0
peaks = np.diff(np.sign(np.diff(ma))) < 0
peaks = np.where(peaks)[0] + 1
number_of_states = sum(ma[peaks] > threshold)
plt.plot(hists[1][peaks][ma[peaks] > threshold], ma[peaks][ma[peaks] > threshold], 'o', markersize=10, label='peaks',
         color='g')
plt.legend()
plt.show()

print(f'Number of states: {number_of_states}')
# Out:
# Number of states: 23

# %%
# DBSCAN on hists[1][peaks], ma[peaks]
peaks_coords = np.array(list(zip(hists[1][peaks], ma[peaks])))
# remove peaks that are less than the threshold
threshold = 5
peaks_coords = peaks_coords[ma[peaks] > threshold]

dbscan = DBSCAN(eps=10, min_samples=1)
dbscan.fit(peaks_coords)
labels = dbscan.labels_
n_clusters_ = len(set(labels)) # - (1 if -1 in labels else 0)
print(f'Number of clusters: {n_clusters_}')

# plot the clusters
plt.scatter(peaks_coords[:, 0], peaks_coords[:, 1], c=labels, cmap='viridis', s=50, alpha=1, marker='o')
plt.plot(hists[1][:-1], ma, 'y', linewidth=1, label='moving average', alpha=1)
plt.legend()
labels
# Out:
# Number of clusters: 3
# array([0, 1, 2])

# %%
lowest_bic = np.infty
lowest_aic = np.infty
best_gmm_bic = None
best_gmm_aic = None

n_components_range = range(1, 10)
bic_scores = []
for n_components in n_components_range:
    gmm = GaussianMixture(n_components=n_components, covariance_type='full')
    gmm.fit(df.signal.values.reshape(-1, 1))
    bic_scores.append(gmm.bic(df.signal.values.reshape(-1, 1)))

# Select the best model based on the lowest BIC score
best_model_index = np.argmin(bic_scores)
best_n_components = n_components_range[best_model_index]
best_gmm = GaussianMixture(n_components=best_n_components, covariance_type='full')
best_gmm.fit(df.signal.values.reshape(-1, 1))

# Print the means, standard deviations, and weights of the fitted normal distributions
means = best_gmm.means_.flatten()
stds = np.sqrt(best_gmm.covariances_).flatten()
weights = best_gmm.weights_

# plot the BIC scores
fig, ax = plt.subplots(1,2)
ax[0].plot(n_components_range, bic_scores, marker='o')
ax[0].set_xlabel('Number of components')
ax[0].set_ylabel('BIC score')
plt.show()

# plot real signal distributions in ax[1]
df.plot(x='time', y='signal', figsize=(30, 5), kind='scatter', alpha=0.5, c='b', ax=ax[1])




print("Number of components:", best_n_components)
print("Means:", means)
print("Standard deviations:", stds)
print("Weights:", weights)
# Out:
# Number of components: 8
# Means: [1.22591913 0.5070631  7.22574806 2.32560392 0.77068967 9.99969482
#  4.10457441 1.45296782]
# Standard deviations: [1.54913765e-01 1.18782401e-01 1.09879009e+00 5.67069374e-01
#  1.39007604e-01 1.00000000e-03 8.34016478e-01 1.57175932e-01]
# Weights: [0.21859341 0.37304303 0.00315709 0.03084665 0.21511983 0.00233322
#  0.00799614 0.14891064]
# /Users/mohamad/PycharmProjects/MastersThesis/venv/lib/python3.9/site-packages/pandas/plotting/_matplotlib/core.py:1256: UserWarning: No data for colormapping provided via 'c'. Parameters 'cmap' will be ignored
#   scatter = ax.scatter(

# %% [markdown]
# ## Classify the signal

# %%
bgm = BayesianGaussianMixture(n_components=n_clusters_, random_state=42).fit(df.signal.values.reshape(-1, 1))
bgm.means_
# Out:
# array([[0.56953366],
#        [3.47505149],
#        [1.26520824]])

# %%
predicted = bgm.predict(df.signal.values.reshape(-1, 1))
df['predicted'] = predicted
conf = bgm.predict_proba(df.signal.values.reshape(-1, 1))
# desc sort conf axis
conf = np.sort(conf, axis=1)[:, ::-1]
df['conf'] = conf[:, 0]

df.plot(x='time', y='signal', figsize=(30, 5), kind='scatter', alpha=df.conf, c='predicted', cmap='viridis',
        colorbar=False)
# Out:
# /var/folders/nz/2mq8cb7968z_6dl9qq938gbc0000gp/T/ipykernel_59224/757020530.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['predicted'] = predicted
# /var/folders/nz/2mq8cb7968z_6dl9qq938gbc0000gp/T/ipykernel_59224/757020530.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['conf'] = conf[:, 0]
# <Axes: xlabel='time', ylabel='signal'>

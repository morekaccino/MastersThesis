# %%
from source.ion_channel import IonChannel
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
# Out:
# /Users/mohamad/PycharmProjects/MastersThesis/venv/lib/python3.9/site-packages/urllib3/__init__.py:34: NotOpenSSLWarning: urllib3 v2.0 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(

# %% [markdown]
# ## Produce some data

# %%
X = []
y = []
for i in range(1500):
    channel = IonChannel(1000)
    X.append(channel.X)
    y.append(channel.y)

# %%
X = np.array(X)
y = np.array(y)
print(X.shape)
print(y.shape)
# Out:
# (1500, 1000)
# (1500, 1000)

# %%
X_train = X[:1000]
y_train = y[:1000]
X_test = X[1000:]
y_test = y[1000:]

# %%
# prepare data for LSTM, X is 100 points and y is 1 point
def prepare_data(X, y, x_len=100, y_len=1, n_samples=1000):
    X_lstm = []
    y_lstm = []
    for i in range(n_samples):
        # randomly select a datapoint in X and y
        idx = np.random.randint(0, len(X)-x_len-y_len)
        # randomly select a starting point in X[idx]
        start = np.random.randint(0, len(X[idx])-x_len-y_len)
        end = start + x_len
        X_lstm.append(X[idx][start:end])
        y_lstm.append(y[idx][end:end+y_len])
        
    return np.array(X_lstm), np.array(y_lstm)

# %%
X_train_lstm, y_train_lstm = prepare_data(X_train, y_train)
X_test_lstm, y_test_lstm = prepare_data(X_test, y_test)

# %%
print(X_train_lstm.shape)
print(y_train_lstm.shape)
# Out:
# (1000, 100)
# (1000, 1)

# %% [markdown]
# ## Build a model

# %%
# y is either 0 or 1. shape of X_train_lstm is (1000, 100), shape of y_train_lstm is (1000, 1)
model = keras.Sequential([
    keras.layers.LSTM(100, input_shape=(100, 1)),
    keras.layers.Dense(1, activation='sigmoid')  
])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])

# %%
model.fit(X_train_lstm, y_train_lstm, epochs=100, validation_data=(X_test_lstm, y_test_lstm))
# Out:
# Epoch 1/100
# 32/32 [==============================] - 1s 40ms/step - loss: 0.2225 - accuracy: 0.9300 - val_loss: 0.1957 - val_accuracy: 0.9390
# Epoch 2/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.2241 - accuracy: 0.9340 - val_loss: 0.2110 - val_accuracy: 0.9370
# Epoch 3/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.2282 - accuracy: 0.9350 - val_loss: 0.1970 - val_accuracy: 0.9390
# Epoch 4/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.2184 - accuracy: 0.9340 - val_loss: 0.1972 - val_accuracy: 0.9380
# Epoch 5/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.2266 - accuracy: 0.9310 - val_loss: 0.2038 - val_accuracy: 0.9420
# Epoch 6/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.2289 - accuracy: 0.9270 - val_loss: 0.2207 - val_accuracy: 0.9350
# Epoch 7/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.2281 - accuracy: 0.9280 - val_loss: 0.2089 - val_accuracy: 0.9350
# Epoch 8/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.2250 - accuracy: 0.9280 - val_loss: 0.1991 - val_accuracy: 0.9370
# Epoch 9/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.2188 - accuracy: 0.9320 - val_loss: 0.1995 - val_accuracy: 0.9460
# Epoch 10/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.2291 - accuracy: 0.9260 - val_loss: 0.1981 - val_accuracy: 0.9440
# Epoch 11/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.2225 - accuracy: 0.9300 - val_loss: 0.1980 - val_accuracy: 0.9390
# Epoch 12/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.2222 - accuracy: 0.9330 - val_loss: 0.1970 - val_accuracy: 0.9390
# Epoch 13/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.2183 - accuracy: 0.9360 - val_loss: 0.2071 - val_accuracy: 0.9370
# Epoch 14/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.2173 - accuracy: 0.9310 - val_loss: 0.2012 - val_accuracy: 0.9410
# Epoch 15/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.2136 - accuracy: 0.9350 - val_loss: 0.1926 - val_accuracy: 0.9450
# Epoch 16/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.2159 - accuracy: 0.9360 - val_loss: 0.2068 - val_accuracy: 0.9350
# Epoch 17/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.2151 - accuracy: 0.9330 - val_loss: 0.2085 - val_accuracy: 0.9320
# Epoch 18/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.2188 - accuracy: 0.9270 - val_loss: 0.2038 - val_accuracy: 0.9390
# Epoch 19/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.2108 - accuracy: 0.9330 - val_loss: 0.2005 - val_accuracy: 0.9400
# Epoch 20/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.2173 - accuracy: 0.9290 - val_loss: 0.1982 - val_accuracy: 0.9360
# Epoch 21/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.2184 - accuracy: 0.9340 - val_loss: 0.1975 - val_accuracy: 0.9390
# Epoch 22/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.2168 - accuracy: 0.9310 - val_loss: 0.1973 - val_accuracy: 0.9420
# Epoch 23/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.2098 - accuracy: 0.9360 - val_loss: 0.1966 - val_accuracy: 0.9380
# Epoch 24/100
# 32/32 [==============================] - 1s 39ms/step - loss: 0.2103 - accuracy: 0.9290 - val_loss: 0.1959 - val_accuracy: 0.9440
# Epoch 25/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.2077 - accuracy: 0.9360 - val_loss: 0.2166 - val_accuracy: 0.9350
# Epoch 26/100
# 32/32 [==============================] - 1s 41ms/step - loss: 0.2475 - accuracy: 0.9200 - val_loss: 0.2042 - val_accuracy: 0.9480
# Epoch 27/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.2339 - accuracy: 0.9390 - val_loss: 0.2084 - val_accuracy: 0.9480
# Epoch 28/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.2235 - accuracy: 0.9330 - val_loss: 0.1956 - val_accuracy: 0.9410
# Epoch 29/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.2175 - accuracy: 0.9340 - val_loss: 0.1929 - val_accuracy: 0.9430
# Epoch 30/100
# 32/32 [==============================] - 1s 37ms/step - loss: 0.2171 - accuracy: 0.9350 - val_loss: 0.2033 - val_accuracy: 0.9350
# Epoch 31/100
# 32/32 [==============================] - 1s 38ms/step - loss: 0.2178 - accuracy: 0.9350 - val_loss: 0.1930 - val_accuracy: 0.9360
# Epoch 32/100
# 32/32 [==============================] - 1s 39ms/step - loss: 0.2098 - accuracy: 0.9340 - val_loss: 0.1934 - val_accuracy: 0.9370
# Epoch 33/100
# 32/32 [==============================] - 1s 38ms/step - loss: 0.2073 - accuracy: 0.9350 - val_loss: 0.1971 - val_accuracy: 0.9400
# Epoch 34/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.2023 - accuracy: 0.9380 - val_loss: 0.2049 - val_accuracy: 0.9350
# Epoch 35/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.1992 - accuracy: 0.9440 - val_loss: 0.2008 - val_accuracy: 0.9360
# Epoch 36/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.2007 - accuracy: 0.9410 - val_loss: 0.2041 - val_accuracy: 0.9380
# Epoch 37/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.2083 - accuracy: 0.9320 - val_loss: 0.2021 - val_accuracy: 0.9380
# Epoch 38/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.1998 - accuracy: 0.9410 - val_loss: 0.2047 - val_accuracy: 0.9400
# Epoch 39/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.1967 - accuracy: 0.9430 - val_loss: 0.2008 - val_accuracy: 0.9390
# Epoch 40/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.1950 - accuracy: 0.9410 - val_loss: 0.1994 - val_accuracy: 0.9380
# Epoch 41/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.1915 - accuracy: 0.9410 - val_loss: 0.2088 - val_accuracy: 0.9350
# Epoch 42/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.1949 - accuracy: 0.9410 - val_loss: 0.2155 - val_accuracy: 0.9360
# Epoch 43/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.2111 - accuracy: 0.9370 - val_loss: 0.2081 - val_accuracy: 0.9420
# Epoch 44/100
# 32/32 [==============================] - 1s 35ms/step - loss: 0.2063 - accuracy: 0.9370 - val_loss: 0.2096 - val_accuracy: 0.9370
# Epoch 45/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.2059 - accuracy: 0.9400 - val_loss: 0.2057 - val_accuracy: 0.9380
# Epoch 46/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.2016 - accuracy: 0.9360 - val_loss: 0.1952 - val_accuracy: 0.9420
# Epoch 47/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.1963 - accuracy: 0.9340 - val_loss: 0.2034 - val_accuracy: 0.9360
# Epoch 48/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.1807 - accuracy: 0.9390 - val_loss: 0.2077 - val_accuracy: 0.9380
# Epoch 49/100
# 32/32 [==============================] - 1s 37ms/step - loss: 0.1983 - accuracy: 0.9400 - val_loss: 0.2025 - val_accuracy: 0.9360
# Epoch 50/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.2074 - accuracy: 0.9380 - val_loss: 0.2190 - val_accuracy: 0.9350
# Epoch 51/100
# 32/32 [==============================] - 1s 37ms/step - loss: 0.2350 - accuracy: 0.9340 - val_loss: 0.2007 - val_accuracy: 0.9380
# Epoch 52/100
# 32/32 [==============================] - 1s 41ms/step - loss: 0.2083 - accuracy: 0.9340 - val_loss: 0.2004 - val_accuracy: 0.9420
# Epoch 53/100
# 32/32 [==============================] - 1s 35ms/step - loss: 0.1967 - accuracy: 0.9450 - val_loss: 0.2063 - val_accuracy: 0.9300
# Epoch 54/100
# 32/32 [==============================] - 2s 49ms/step - loss: 0.1882 - accuracy: 0.9400 - val_loss: 0.2068 - val_accuracy: 0.9380
# Epoch 55/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.1889 - accuracy: 0.9430 - val_loss: 0.2114 - val_accuracy: 0.9370
# Epoch 56/100
# 32/32 [==============================] - 1s 35ms/step - loss: 0.1840 - accuracy: 0.9410 - val_loss: 0.2025 - val_accuracy: 0.9380
# Epoch 57/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.1828 - accuracy: 0.9440 - val_loss: 0.2056 - val_accuracy: 0.9420
# Epoch 58/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.1839 - accuracy: 0.9420 - val_loss: 0.2082 - val_accuracy: 0.9340
# Epoch 59/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.1735 - accuracy: 0.9440 - val_loss: 0.1993 - val_accuracy: 0.9390
# Epoch 60/100
# 32/32 [==============================] - 1s 37ms/step - loss: 0.1748 - accuracy: 0.9410 - val_loss: 0.2284 - val_accuracy: 0.9300
# Epoch 61/100
# 32/32 [==============================] - 1s 35ms/step - loss: 0.1946 - accuracy: 0.9390 - val_loss: 0.2166 - val_accuracy: 0.9270
# Epoch 62/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.2111 - accuracy: 0.9330 - val_loss: 0.2129 - val_accuracy: 0.9300
# Epoch 63/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.1797 - accuracy: 0.9430 - val_loss: 0.2108 - val_accuracy: 0.9340
# Epoch 64/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.1767 - accuracy: 0.9430 - val_loss: 0.2055 - val_accuracy: 0.9360
# Epoch 65/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.1741 - accuracy: 0.9460 - val_loss: 0.2061 - val_accuracy: 0.9380
# Epoch 66/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.1700 - accuracy: 0.9410 - val_loss: 0.2068 - val_accuracy: 0.9380
# Epoch 67/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.1601 - accuracy: 0.9480 - val_loss: 0.2100 - val_accuracy: 0.9350
# Epoch 68/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.1643 - accuracy: 0.9470 - val_loss: 0.2130 - val_accuracy: 0.9290
# Epoch 69/100
# 32/32 [==============================] - 1s 35ms/step - loss: 0.1903 - accuracy: 0.9370 - val_loss: 0.2060 - val_accuracy: 0.9380
# Epoch 70/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.1716 - accuracy: 0.9450 - val_loss: 0.2008 - val_accuracy: 0.9370
# Epoch 71/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.1620 - accuracy: 0.9460 - val_loss: 0.2138 - val_accuracy: 0.9340
# Epoch 72/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.1624 - accuracy: 0.9500 - val_loss: 0.2168 - val_accuracy: 0.9380
# Epoch 73/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.1625 - accuracy: 0.9520 - val_loss: 0.2200 - val_accuracy: 0.9270
# Epoch 74/100
# 32/32 [==============================] - 1s 35ms/step - loss: 0.1506 - accuracy: 0.9560 - val_loss: 0.2110 - val_accuracy: 0.9340
# Epoch 75/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.1490 - accuracy: 0.9520 - val_loss: 0.2193 - val_accuracy: 0.9330
# Epoch 76/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.1564 - accuracy: 0.9510 - val_loss: 0.2242 - val_accuracy: 0.9270
# Epoch 77/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.1471 - accuracy: 0.9520 - val_loss: 0.2207 - val_accuracy: 0.9290
# Epoch 78/100
# 32/32 [==============================] - 1s 35ms/step - loss: 0.1476 - accuracy: 0.9490 - val_loss: 0.2332 - val_accuracy: 0.9270
# Epoch 79/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.1603 - accuracy: 0.9530 - val_loss: 0.2376 - val_accuracy: 0.9210
# Epoch 80/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.1525 - accuracy: 0.9550 - val_loss: 0.2151 - val_accuracy: 0.9370
# Epoch 81/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.1380 - accuracy: 0.9580 - val_loss: 0.2252 - val_accuracy: 0.9300
# Epoch 82/100
# 32/32 [==============================] - 1s 35ms/step - loss: 0.1317 - accuracy: 0.9620 - val_loss: 0.2237 - val_accuracy: 0.9330
# Epoch 83/100
# 32/32 [==============================] - 1s 39ms/step - loss: 0.1403 - accuracy: 0.9570 - val_loss: 0.2273 - val_accuracy: 0.9340
# Epoch 84/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.1335 - accuracy: 0.9560 - val_loss: 0.2333 - val_accuracy: 0.9280
# Epoch 85/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.1301 - accuracy: 0.9610 - val_loss: 0.2464 - val_accuracy: 0.9300
# Epoch 86/100
# 32/32 [==============================] - 1s 37ms/step - loss: 0.1739 - accuracy: 0.9460 - val_loss: 0.2185 - val_accuracy: 0.9330
# Epoch 87/100
# 32/32 [==============================] - 1s 35ms/step - loss: 0.1566 - accuracy: 0.9510 - val_loss: 0.2327 - val_accuracy: 0.9290
# Epoch 88/100
# 32/32 [==============================] - 1s 35ms/step - loss: 0.1541 - accuracy: 0.9560 - val_loss: 0.2314 - val_accuracy: 0.9310
# Epoch 89/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.1503 - accuracy: 0.9570 - val_loss: 0.2187 - val_accuracy: 0.9400
# Epoch 90/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.1365 - accuracy: 0.9620 - val_loss: 0.2486 - val_accuracy: 0.9200
# Epoch 91/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.1223 - accuracy: 0.9660 - val_loss: 0.2371 - val_accuracy: 0.9320
# Epoch 92/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.1484 - accuracy: 0.9540 - val_loss: 0.2398 - val_accuracy: 0.9290
# Epoch 93/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.1449 - accuracy: 0.9510 - val_loss: 0.2310 - val_accuracy: 0.9320
# Epoch 94/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.1290 - accuracy: 0.9650 - val_loss: 0.2404 - val_accuracy: 0.9240
# Epoch 95/100
# 32/32 [==============================] - 1s 35ms/step - loss: 0.1270 - accuracy: 0.9620 - val_loss: 0.2258 - val_accuracy: 0.9370
# Epoch 96/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.1370 - accuracy: 0.9600 - val_loss: 0.2182 - val_accuracy: 0.9310
# Epoch 97/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.1214 - accuracy: 0.9660 - val_loss: 0.2400 - val_accuracy: 0.9270
# Epoch 98/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.1233 - accuracy: 0.9630 - val_loss: 0.2391 - val_accuracy: 0.9260
# Epoch 99/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.1129 - accuracy: 0.9650 - val_loss: 0.2389 - val_accuracy: 0.9320
# Epoch 100/100
# 32/32 [==============================] - 1s 36ms/step - loss: 0.1090 - accuracy: 0.9650 - val_loss: 0.2355 - val_accuracy: 0.9320

# %% [markdown]
# ## Test the model

# %%
y_pred = model.predict(X_test_lstm)
# round the prediction to 0 or 1
y_pred = np.round(y_pred)
# Out:
# 32/32 [==============================] - 0s 9ms/step

# %%
from sklearn.metrics import accuracy_score
accuracy_score(y_test_lstm, y_pred)
# Out:
# 0.932

# %%
def prepare_test_data(X, y, x_len=100, y_len=1):
    X_lstm = []
    y_lstm = []
    for i in range(len(X)):
        for j in range(len(X[i])-x_len-y_len):
            X_lstm.append(X[i][j:j+x_len])
            y_lstm.append(y[i][j+x_len:j+x_len+y_len])
    return np.array(X_lstm), np.array(y_lstm)

# %%
test_ion = IonChannel(1000)
X_test_ion = test_ion.X
y_test_ion = test_ion.y

X_test_ion_lstm, y_test_ion_lstm = prepare_test_data([X_test_ion], [y_test_ion])
print(X_test_ion_lstm.shape)
print(y_test_ion_lstm.shape)
# Out:
# (899, 100)
# (899, 1)

# %%
y_pred_ion = model.predict(X_test_ion_lstm)
y_pred_ion = np.round(y_pred_ion)
# Out:
# 29/29 [==============================] - 0s 9ms/step

# %%
plt.figure(figsize=(30, 5))
plt.plot(y_test_ion_lstm, color='green', label='true', linestyle='solid', linewidth=5)
plt.plot(y_pred_ion, color='red', label='pred', linestyle='dashed', linewidth=2)
# X_test_ion scatter plot
# plt.scatter(range(len(X_test_ion)), X_test_ion, color='green', label='true')
plt.legend()

# %%
# normalize X_test_ion to be between 2 and 0
X_test_ion = (X_test_ion - np.min(X_test_ion)) / (np.max(X_test_ion) - np.min(X_test_ion)) * 2.5 - 0.4

plt.figure(figsize=(30, 5))
# start from 100
plt.plot(range(100, 100+len(y_test_ion_lstm)), y_test_ion_lstm, color='green', label='true', linestyle='solid', linewidth=5)
# start from 100
plt.plot(range(100, 100+len(y_pred_ion)), y_pred_ion, color='red', label='pred', linestyle='dashed', linewidth=2)
# X_test_ion scatter plot
plt.scatter(range(len(X_test_ion)), X_test_ion, color='blue', label='true', alpha=0.5)
plt.legend()

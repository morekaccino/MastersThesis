# %%
import numpy as np
import pandas as pd
from source.moreka import AxonData
from sklearn.cluster import DBSCAN
from sklearn.preprocessing import StandardScaler
from sklearn.metrics.pairwise import euclidean_distances
from scipy.spatial.distance import pdist, squareform
import matplotlib.pyplot as plt

# %%
data = AxonData(dirname='./data')
df = data[3]#.iloc[::50, :]

df['difference'] = abs(df['signal'].diff().fillna(0))
df
# Out:
#            time    signal  difference
# 0        0.0000  1.203003    0.000000
# 1        0.0001  1.250000    0.046997
# 2        0.0002  1.302795    0.052795
# 3        0.0003  1.333008    0.030212
# 4        0.0004  1.382141    0.049133
# ...         ...       ...         ...
# 599995  59.9995  0.670471    0.019531
# 599996  59.9996  0.685120    0.014648
# 599997  59.9997  0.678101    0.007019
# 599998  59.9998  0.600281    0.077820
# 599999  59.9999  0.523987    0.076294
#
# [600000 rows x 3 columns]

# %%
df.plot(x='time', y='difference', kind='scatter', alpha=0.3, s=5)
df.plot(x='time', y='signal', kind='scatter', alpha=0.3, s=5)
# Out:
# <Axes: xlabel='time', ylabel='signal'>

# %%
diff = np.array(df.difference)
stds = []
means = []
window_size = 100
for i in range(0, len(diff), window_size):
    stds.append(diff[i:i+window_size].std())
    means.append(diff[i:i+window_size].mean())

# %%
plt.plot(range(len(stds)), stds)

# %%
plt.plot(range(len(stds)), means)
